# %%
from hrepr import hrepr
from hrepr.core import Hrepr


class MyIntRepr(Hrepr):
    def hrepr_resources(self, cls: int):
        return self.H.style(".my-integer { color: fuchsia; }")

    def hrepr(self, n: int):
        return self.H.span["my-integer"]("The number ", str(n))

    def hrepr_short(self, n: int):
        return self.H.span["my-integer"]("The number ", str(n))

    def hrepr(self, n: str):
        return self.H.span["my-integer"](str(n))


hrepr([1, 2, 3, 4, "woof"], mixins=MyIntRepr)
# Out:
# <div class="hreprt-list hrepr-titled-h"><div class="hrepr-title">[</div><div class="hrepr-contents-h"><span class="my-integer">The number 1</span><span class="my-integer">The number 2</span><span class="my-integer">The number 3</span><span class="my-integer">The number 4</span><span class="my-integer">woof</span></div><div class="hrepr-title">]</div></div>
